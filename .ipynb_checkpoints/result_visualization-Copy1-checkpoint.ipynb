# %%
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
dataset = "OAI"
test_nb = 10

Nacq = 5

dir = dataset + "/Sim/Test" + str(test_nb)
Nsim = 200
acc = np.zeros((5, Nacq+1))
H = np.zeros((5, Nacq+1))


for filename in os.listdir(dir):
    if filename[0] == "a":
        acc_file = os.path.join(dir, filename)
        acc_tmp = np.load(acc_file)
        acc += acc_tmp
    elif filename[0] == "H":
        H_file = os.path.join(dir, filename)
        H_tmp = np.load(H_file)
        H += H_tmp
acc = acc/Nsim
H = H/Nsim
print(acc)
print(H)
# Out:
# [[0.6705 0.6705 0.6705 0.6705 0.6705 0.6705]
#  [0.6705 0.6705 0.6705 0.6705 0.6705 0.6705]
#  [0.6705 0.6705 0.6705 0.6705 0.6705 0.6705]
#  [0.6705 0.6705 0.6705 0.6705 0.6705 0.6705]
#  [0.6705 0.6705 0.6705 0.6705 0.6705 0.6705]]
# [[1.67481065 1.66542998 1.66820926 1.67977028 1.68723865 1.64843016]
#  [1.65698108 1.63650358 1.63234911 1.60670846 1.60265466 1.62739657]
#  [1.68120542 1.66070712 1.67683708 1.67115733 1.6558079  1.70626641]
#  [1.66558663 1.64292051 1.63269319 1.67218082 1.6683353  1.66388872]
#  [1.65510807 1.66379511 1.65077096 1.64858266 1.65750764 1.68530575]]

# %%
figure = plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.plot(acc[0], color='blue', label='RS')
plt.plot(acc[1], color='orange', label='EIG/US')
plt.plot(acc[2], color='green', label='D-US')
plt.plot(acc[3], color='red', label='T-EIG')
plt.plot(acc[4], color='purple', label='D-EIG')
# plt.plot(acc[5], color='black', label='DM-Aware')
plt.legend()
plt.title("Accuracy")

plt.subplot(1,2,2)
plt.plot(H[0], color='blue', label='RS')
plt.plot(H[1], color='orange', label='EIG/US')
plt.plot(H[2], color='green', label='D-US')
plt.plot(H[3], color='red', label='T-EIG')
plt.plot(H[4], color='purple', label='D-EIG')
# plt.plot(H[5], color='black', label='DM-Aware')
plt.legend()
plt.title("Entropy")
plt.show()
